# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
AV1["timestep_diff"]=AV1["timestep"] - AV1["timestep"].shift(1).fillna(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 AV1["timestep_diff"]=AV1["timestep"] - AV1["timestep"].shift(1).fillna(0)
#
# NameError: name 'AV1' is not defined

# %%
AV_num = 20
AV_length = 300
AV1 = pd.read_csv("log\TV\DQN_sumo-v0_log_"+str(AV_num)+"_0.csv",index_col=None)

# %%
AV1
# Out:
#      episode  timestep     reward  if_collision  collision_rate  \
# 0          0      3000 -3516.0407             0        0.200000
# 1          1      5917 -3398.6120             1        0.200000
# 2          2      8917 -3475.0310             0        0.200000
# 3          3     11917 -3491.0727             0        0.200000
# 4          4     14917 -3466.4713             0        0.200000
# ..       ...       ...        ...           ...             ...
# 126      126    292393     0.0000             0        0.096774
# 127      127    294647     0.0000             0        0.096774
# 128      128    296835     0.0000             0        0.096774
# 129      129    299315     0.0000             0        0.096774
# 130      130    301552     0.0000             0        0.096774
#
#      adversarial_counts   epsilon  av_speed_avg  av_total_risk_avg  \
# 0                     0  0.000000      0.539728           0.151107
# 1                     0  0.000000      0.592446           0.265864
# 2                     0  0.000000      0.419793           0.097933
# 3                     0  0.000000      0.426182           0.071577
# 4                     0  0.000000      0.283525           0.047229
# ..                  ...       ...           ...                ...
# 126               43228  0.369588     31.318639           0.811875
# 127               44253  0.369588     31.032788           0.572955
# 128               45904  0.369588     31.970241           0.954352
# 129               46503  0.369588     28.216713           0.251035
# 130               47829  0.369588     31.273880           0.712892
#
#      av_distance  av_running_time  av_acc_avg  av_dece_avg  av_left_avg  \
# 0     161.884202            360.1    3.000000          NaN     0.098667
# 1     172.776080            351.8    3.000000          NaN     0.099074
# 2     125.935416            360.1    3.000000          NaN     0.102000
# 3     127.852078            360.1    3.000000          NaN     0.105000
# 4      85.018269            360.1    3.000000          NaN     0.092000
# ..           ...              ...         ...          ...          ...
# 126  6992.684675            283.5    3.000000    -3.701160     0.081916
# 127  6992.073674            285.5    2.999477          NaN     0.104703
# 128  6992.962994            278.9    2.999181          NaN     0.081810
# 129  6994.333343            308.1    3.000000    -2.471214     0.067339
# 130  6992.897908            283.8    3.000000    -3.362474     0.106840
#
#      av_right_avg
# 0        0.100667
# 1        0.099417
# 2        0.096333
# 3        0.095333
# 4        0.089000
# ..            ...
# 126      0.007610
# 127      0.005324
# 128      0.005941
# 129      0.002419
# 130      0.004917
#
# [131 rows x 15 columns]

# %%
AV1_1 = AV1[AV1['reward'] != 0]

# %%
AV1_1
# Out:
#     episode  timestep     reward  if_collision  collision_rate  \
# 0         0      3000 -3516.0407             0        0.200000
# 1         1      5917 -3398.6120             1        0.200000
# 2         2      8917 -3475.0310             0        0.200000
# 3         3     11917 -3491.0727             0        0.200000
# 4         4     14917 -3466.4713             0        0.200000
# ..      ...       ...        ...           ...             ...
# 83       83    208968  1300.0499             0        0.129032
# 84       84    211323  1603.3315             0        0.129032
# 85       85    213475  1447.0619             0        0.129032
# 86       86    215806  1564.3149             0        0.129032
# 87       87    218133  1558.9054             0        0.000000
#
#     adversarial_counts   epsilon  av_speed_avg  av_total_risk_avg  \
# 0                    0  0.000000      0.539728           0.151107
# 1                    0  0.000000      0.592446           0.265864
# 2                    0  0.000000      0.419793           0.097933
# 3                    0  0.000000      0.426182           0.071577
# 4                    0  0.000000      0.283525           0.047229
# ..                 ...       ...           ...                ...
# 83                   0  0.284318     31.720495           0.861000
# 84                   0  0.284318     29.706725           0.544384
# 85                   0  0.284318     32.513289           0.811755
# 86                   0  0.284318     30.011873           0.436132
# 87                   0  1.000000     30.068711           0.665552
#
#     av_distance  av_running_time  av_acc_avg  av_dece_avg  av_left_avg  \
# 0    161.884202            360.1    3.000000          NaN     0.098667
# 1    172.776080            351.8    3.000000          NaN     0.099074
# 2    125.935416            360.1    3.000000          NaN     0.102000
# 3    127.852078            360.1    3.000000          NaN     0.105000
# 4     85.018269            360.1    3.000000          NaN     0.092000
# ..          ...              ...         ...          ...          ...
# 83  6994.963820            280.7    2.999407          NaN     0.248867
# 84  6992.711103            295.6    3.000000    -1.526482     0.216985
# 85  6993.486637            275.3    2.999130          NaN     0.223513
# 86  6993.028641            293.2    3.000000    -3.631406     0.240669
# 87  6993.873138            292.8    3.000000    -1.380189     0.216158
#
#     av_right_avg
# 0       0.100667
# 1       0.099417
# 2       0.096333
# 3       0.095333
# 4       0.089000
# ..           ...
# 83      0.014053
# 84      0.016136
# 85      0.012546
# 86      0.008580
# 87      0.013322
#
# [88 rows x 15 columns]

# %%
plt.plot(np.arange(len(AV1)),AV1["collision_rate"])

# %%
plt.plot(np.arange(len(AV1)),AV1["av_total_risk_avg"])

# %%
plt.plot(np.arange(len(AV1)),AV1["epsilon"])

# %%
plt.plot(np.arange(len(AV1)),AV1["collision_rate"])

# %%
plt.plot(np.arange(len(AV1_1)),AV1_1["reward"])

# %%
BV_num = 20
BV1 = pd.read_csv("log\BV\PPO_sumo-v0_log_"+str(BV_num)+"_0.csv",index_col=None)

# %%
def bv_data_preprocessing(data):
    data["adversarial_counts_diff"]=data["adversarial_counts"] - data["adversarial_counts"].shift(1).fillna(0)
    data["average_reward"] = data["reward"] / data["adversarial_counts_diff"]
    return data

# %%
BV1 = bv_data_preprocessing(BV1)

# %%
BV1
# Out:
#      episode  timestep  collision_counts  adversarial_counts   reward  \
# 0          0      3000                 0                   0   0.0000
# 1          1      5917                 0                   0   0.0000
# 2          2      8917                 1                   0   0.0000
# 3          3     11917                 1                   0   0.0000
# 4          4     14917                 1                   0   0.0000
# ..       ...       ...               ...                 ...      ...
# 126      126    292393                13               43228  49.7869
# 127      127    294647                13               44253 -23.1986
# 128      128    296835                13               45904  40.7328
# 129      129    299315                13               46503 -16.0834
# 130      130    301552                13               47829  16.6938
#
#      adversarial_counts_diff  average_reward
# 0                        0.0             NaN
# 1                        0.0             NaN
# 2                        0.0             NaN
# 3                        0.0             NaN
# 4                        0.0             NaN
# ..                       ...             ...
# 126                   1486.0        0.033504
# 127                   1025.0       -0.022633
# 128                   1651.0        0.024672
# 129                    599.0       -0.026850
# 130                   1326.0        0.012590
#
# [131 rows x 7 columns]

# %%
plt.plot(BV1["reward"])

# %%
plt.plot(BV1["average_reward"])

# %%
def data_preprocessing(data):
    data["timestep_diff"]=data["timestep"] - data["timestep"].shift(1).fillna(0)
    data["average_reward"] = data["reward"] / data["timestep_diff"]
    return data

# %%
AV_num = 75
AV_length = 300
AV1 = pd.read_csv("runs\sumo-v0\DQN_sumo-v0_log_"+str(AV_num)+"_1.csv",index_col=None)
AV2 = pd.read_csv("runs\sumo-v0\DQN_sumo-v0_log_"+str(AV_num)+"_2.csv",index_col=None)
AV3 = pd.read_csv("runs\sumo-v0\DQN_sumo-v0_log_"+str(AV_num)+"_3.csv",index_col=None)
AV4 = pd.read_csv("runs\sumo-v0\DQN_sumo-v0_log_"+str(AV_num)+"_4.csv",index_col=None)
AV5 = pd.read_csv("runs\sumo-v0\DQN_sumo-v0_log_"+str(AV_num)+"_5.csv",index_col=None)
AV1 = data_preprocessing(AV1)
AV2 = data_preprocessing(AV2)
AV3 = data_preprocessing(AV3)
AV4 = data_preprocessing(AV4)
AV5 = data_preprocessing(AV5)



AV = pd.concat([AV1[:AV_length],AV2[:AV_length],AV3[:AV_length],AV4[:AV_length],AV5[:AV_length]])

# %%
AV1
# Out:
#       episode  timestep     reward  if_collision  collision_rate  \
# 0           0      3000 -7126.1048             0        0.000000
# 1           1      5045 -5946.7022             1        0.500000
# 2           2      8045 -8758.2238             0        0.333333
# 3           3     11045 -8581.7618             0        0.250000
# 4           4     13792 -7277.9560             1        0.400000
# ...       ...       ...        ...           ...             ...
# 2706     2706   2995968  1741.5464             0        0.631696
# 2707     2707   2998255  1877.3775             0        0.631462
# 2708     2708   2998410  -143.9818             1        0.631598
# 2709     2709   2998576  -125.8594             1        0.631734
# 2710     2710   3000856  1875.8827             0        0.631501
#
#       adversarial_counts   epsilon  av_speed_avg  av_total_risk_avg  \
# 0                      0  1.000000      6.162139           0.196776
# 1                   2045  0.048581      1.585265          -0.116533
# 2                   2210  0.094757      1.683251          -0.155336
# 3                   2511  0.138606      1.968736           0.071977
# 4                   2869  0.071967      3.824310           0.207457
# ...                  ...       ...           ...                ...
# 2706              123268  0.028610     29.913224          -0.361645
# 2707              123335  0.028638     30.576425          -0.238202
# 2708              123338  0.028622     16.722745           0.048555
# 2709              123341  0.028605     17.823914           0.203589
# 2710              123416  0.028633     30.664023          -0.217265
#
#       av_distance  av_running_time  av_acc_avg  av_dece_avg  av_left_avg  \
# 0     1848.941130            360.1    2.999000     0.000000     0.087333
# 1      324.340357            264.6    2.998534     0.000000     0.099756
# 2      504.957850            360.1    2.999000     0.000000     0.085000
# 3      590.608577            360.1    2.999000     0.000000     0.084667
# 4     1050.647095            334.8    2.998908     0.000000     0.087004
# ...           ...              ...         ...          ...          ...
# 2706  6993.530918            293.9    2.998717    -1.325379     0.260907
# 2707  6993.280195            288.8    2.998688    -0.790425     0.071272
# 2708   257.879397             75.6    2.980769     0.000000     0.174194
# 2709   294.499866             76.7    2.982036     0.000000     0.090361
# 2710  6991.946605            288.1    2.998684    -1.813937     0.096930
#
#       av_right_avg  timestep_diff  average_reward
# 0         0.099333         3000.0       -2.375368
# 1         0.089487         2045.0       -2.907923
# 2         0.086000         3000.0       -2.919408
# 3         0.094667         3000.0       -2.860587
# 4         0.105206         2747.0       -2.649420
# ...            ...            ...             ...
# 2706      0.039778         2338.0        0.744887
# 2707      0.074770         2287.0        0.820891
# 2708      0.187097          155.0       -0.928915
# 2709      0.192771          166.0       -0.758189
# 2710      0.073246         2280.0        0.822756
#
# [2711 rows x 17 columns]

# %%
sns.lineplot(x=AV["episode"],y=AV["timestep_diff"])
# Out:
# <Axes: xlabel='episode', ylabel='timestep_diff'>

# %%
sns.lineplot(x=AV["episode"],y=AV["av_speed_avg"])
plt.savefig("av_speed_avg.png")

# %%
sns.lineplot(x=AV["episode"],y=AV["epsilon"])
# Out:
# <Axes: xlabel='episode', ylabel='epsilon'>

# %%
sns.lineplot(x=AV["episode"],y=AV["av_total_risk_avg"])
# Out:
# <Axes: xlabel='episode', ylabel='av_total_risk_avg'>

# %%
sns.lineplot(x=AV["episode"],y=AV["average_reward"])
plt.savefig("av_average_reward.png")

# %%
sns.lineplot(x=AV["episode"],y=AV["collision_rate"])
plt.savefig("collision_rate.png")

# %%
sns.lineplot(x=AV["episode"],y=AV["reward"])
# Out:
# <Axes: xlabel='episode', ylabel='reward'>

# %%
BV1
# Out:
#       episode  timestep  collision_counts  adversarial_counts    reward
# 0           1      5045                 1                2045 -824.5271
# 1           4     13792                 2                2869 -319.4197
# 2           5     15198                 3                2965  -44.0154
# 3          11     31331                 4                4286 -375.0416
# 4          15     38244                 5                5033 -184.9058
# ...       ...       ...               ...                 ...       ...
# 1707     2701   2988740              1708              123081   -1.0000
# 1708     2702   2988903              1709              123085   -0.7827
# 1709     2704   2991353              1710              123149  -24.7003
# 1710     2708   2998410              1711              123338  -86.5883
# 1711     2709   2998576              1712              123341   -1.5000
#
# [1712 rows x 5 columns]

# %%
def BV_data_preprocessing(data):
    data["adversarial_counts_diff"]=data["adversarial_counts"] - data["adversarial_counts"].shift(1).fillna(0)
    data["average_reward"] = data["reward"] / (data["adversarial_counts_diff"]+1)
    return data

# %%
BV_num = 44
length = 100
BV1 = pd.read_csv("PPO_logs\sumo-v0\PPO_sumo-v0_log_"+str(BV_num)+"_1.csv",index_col=None)
BV2 = pd.read_csv("PPO_logs\sumo-v0\PPO_sumo-v0_log_"+str(BV_num)+"_2.csv",index_col=None)
BV3 = pd.read_csv("PPO_logs\sumo-v0\PPO_sumo-v0_log_"+str(BV_num)+"_3.csv",index_col=None)
BV4 = pd.read_csv("PPO_logs\sumo-v0\PPO_sumo-v0_log_"+str(BV_num)+"_4.csv",index_col=None)
BV5 = pd.read_csv("PPO_logs\sumo-v0\PPO_sumo-v0_log_"+str(BV_num)+"_5.csv",index_col=None)
BV1 = BV_data_preprocessing(BV1)
BV2 = BV_data_preprocessing(BV2)
BV3 = BV_data_preprocessing(BV3)
BV4 = BV_data_preprocessing(BV4)
BV5 = BV_data_preprocessing(BV5)



BV = pd.concat([BV1[:length],BV2[:length],BV3[:length],BV4[:length],BV5[:length]])

# %%
BV1
# Out:
#       episode  timestep  collision_counts  adversarial_counts    reward  \
# 0           1      5045                 1                2045 -824.5271
# 1           4     13792                 2                2869 -319.4197
# 2           5     15198                 3                2965  -44.0154
# 3          11     31331                 4                4286 -375.0416
# 4          15     38244                 5                5033 -184.9058
# ...       ...       ...               ...                 ...       ...
# 1707     2701   2988740              1708              123081   -1.0000
# 1708     2702   2988903              1709              123085   -0.7827
# 1709     2704   2991353              1710              123149  -24.7003
# 1710     2708   2998410              1711              123338  -86.5883
# 1711     2709   2998576              1712              123341   -1.5000
#
#       adversarial_counts_diff  average_reward
# 0                      2045.0       -0.402995
# 1                       824.0       -0.387175
# 2                        96.0       -0.453767
# 3                      1321.0       -0.283693
# 4                       747.0       -0.247200
# ...                       ...             ...
# 1707                      2.0       -0.333333
# 1708                      4.0       -0.156540
# 1709                     64.0       -0.380005
# 1710                    189.0       -0.455728
# 1711                      3.0       -0.375000
#
# [1712 rows x 7 columns]

# %%
sns.lineplot(x=BV["collision_counts"],y=BV["average_reward"])
# Out:
# <Axes: xlabel='collision_counts', ylabel='average_reward'>

# %%
sns.lineplot(x=BV["collision_counts"],y=BV["reward"])
plt.savefig("bv_reward.png")

# %%
fig, ax = plt.subplots()

sns.lineplot(x=BV["episode"],y=BV["collision_counts"])
ax.set_aspect('equal')
