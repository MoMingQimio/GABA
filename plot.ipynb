# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
AV = pd.read_csv("runs\sumo-v0\DQN_sumo-v0_log_32_1.csv",index_col=None)

# %%
AV[""]
# Out:
#      episode  timestep     reward  if_collision  collision_rate  \
# 0          0      3000 -8450.4755             0        0.000000
# 1          1      5724 -7263.9026             0        0.000000
# 2          2      7127 -4246.4410             1        0.333333
# 3          3     10127 -8529.6211             0        0.250000
# 4          4     10291  -493.7571             1        0.400000
# ..       ...       ...        ...           ...             ...
# 304      304    443425  1794.7368             0        0.511475
# 305      305    443599  -120.7518             1        0.513072
# 306      306    443770  -123.4889             1        0.514658
# 307      307    446076  1632.5872             0        0.512987
# 308      308    446244  -118.6512             1        0.514563
#
#      adversarial_counts   epsilon  av_speed_avg  av_total_risk_avg  \
# 0                  2999  1.000000      2.410016          -0.012395
# ...

# %%
plt.plot(AV[""])
